# %% [markdown]
# # Configure Environment
#
# ```sh
# python3 -m venv venv
# source venv/bin/activate
#
# # install necessary packages
# pip3 install selenium
# ```
#
# After installing Selenium, import the following modules:

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# # Using Selenium Locators
#
# For the following example, we will use [Washtenaw County precinct voter information](https://electionresults.ewashtenaw.org/electionreporting/nov2024/indexprecinctreport.html) to show how to get a variety of elements from a static webpage using Selenium Locators
#
# First, we need to find where in our filesystem the browser of our choice lives.
# ## MacOS
# On MacOS systems, you can typically find this in `/Applications/(Your browser's name).app/Contents/MacOS/(Your browser's name)`
# ## Linux/WSL
# On Linux systems, you can find the browser's location using the `which` command (e.g. `which google-chrome-stable`)
#
# For the following example, Brave Browser on MacOS will be used.

# %%
brave_path = "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"

# %% [markdown]
# ## Installing ChromeDriver
#
# In addition to the browser executable, we also need a corresponding driver for Selenium to interface with it. Assuming that the browser is Chromium-based, we will be using ChromeDriver which can be downloaded [here](https://sites.google.com/chromium.org/driver/). After installing, we can specify the executable's path:

# %%
chromedriver_path = "./chromedriver-mac-arm64/chromedriver"

# %% [markdown]
# We can now instantiate the WebDriver with our predefined options:

# %%
# Set up chrome options
opt = Options()
opt.binary_location = brave_path

# Instantiate driver
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service, options=opt)

# %% [markdown]
# Now, lets get the HTML content for the Washtenaw County precinct voter data

# %%
# Send HTTP request
driver.get("https://electionresults.ewashtenaw.org/electionreporting/nov2024/indexprecinctreport.html")

# %% [markdown]
# From this page, we see that there is a long list of links for each precinct. Let's start by gathering all of this links so that we can traverse every precinct accordingly. In order to do this, we can simply get all the `<a>` elements on the page since all links on the page are a link to a precinct.

# %%
# get all <a> elements
rows = driver.find_elements(By.TAG_NAME, "a")

# %% [markdown]
# Now that we have all the `<a>` elements, we need to get the link URLs. We can do this by accessing the `href` attribute for each:

# %%
# Get URLs
hrefs = []
for row in rows:
	hrefs.append(row.get_attribute("href"))

# %% [markdown]
# If we visit any of these precinct links, we will find that they all share the same general structure. For example, each precinct page has exactly one `<font>` element which has a class of `h2`, which corresponds to the precinct's name. We can use this information to get the precinct name for every precinct.
#
# Let's say we also want to tally the total number of voters for all precincts in Ann Arbor. Using the same method we used to find the precinct name, we can see that the number of registered voters is always put in the second `<td>` element of the page as a whole. To do this, let's use the following XPath statement:
#
# `(//td)[2]`
#
# Let's also break down how we came up with the syntax:
# 1. `//td`
# - `//`: This selects all elements in the document that match the following node test, regardless of their position in the document tree
#
# - `td`: This is the node test. It selects all <td> elements (table data cells in HTML).
#
# So, `//td` selects all `<td>` elements in the entire HTML document.
#
# 2. `(//td)`
# - The parentheses `()` are used to group the expression `//td`. This is useful when you want to apply an index or other operations to the result of the grouped expression.
#
# 3. `[2]`
# - The `[2]` is a predicate. It filters the result of the grouped expression `(//td)` to select the second matching element.
#
# In XPath, indexing starts at 1 (not 0, as in many programming languages).

# %%
total_reg_voters = 0
for href in hrefs:
	# recurse through each row
	driver.get(href)
	print(f"Precinct: {driver.find_element(By.CLASS_NAME, 'h2').text}")
	reg_voters = driver.find_element(By.XPATH, "(//td)[2]")
	print(f"Registered Voters: {reg_voters.text}")
	total_reg_voters += int(reg_voters.text.replace(",",""))
	print("")
# Out:
# Precinct: CITY OF ANN ARBOR, WARD 1, PRECINCT
# Precinct: CHARTER TOWNSHIP OF SUPERIOR, PRECINCT 5
# Registered Voters: 3,010
#
# Precinct: SYLVAN TOWNSHIP, PRECINCT 1
# Registered Voters: 3,213
#
# Precinct: WEBSTER TOWNSHIP, PRECINCT 1
# Registered Voters: 1,816
#
# Precinct: WEBSTER TOWNSHIP, PRECINCT 2
# Registered Voters: 1,943
#
# Precinct: WEBSTER TOWNSHIP, PRECINCT 3
# Registered Voters: 2,264
#
# Precinct: YORK TOWNSHIP, PRECINCT 1
# Registered Voters: 2,247
#
# Precinct: YORK TOWNSHIP, PRECINCT 2
# Registered Voters: 4,102
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 1
# Registered Voters: 3,163
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 2
# Registered Voters: 3,105
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 3
# Registered Voters: 3,957
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 4
# Registered Voters: 4,398
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 5
# Registered Voters: 4,264
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 6
# Registered Voters: 4,521
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 7
# Registered Voters: 4,315
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 8
# Registered Voters: 5,179
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 9
# Registered Voters: 4,727
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 10
# Registered Voters: 4,991
#
# Precinct: YPSILANTI TOWNSHIP, PRECINCT 11
# Registered Voters: 4,875

# %% [markdown]
# Finally, lets print the total registered voters count

# %%
print(f"Total Registered Voters: {total_reg_voters}")
# Out:
# Total Registered Voters: 337738

# %% [markdown]
# # Using Selenium Interactions & Actions API
#
# For the next example, we will be using TikTok to show how we can use Interactions and the Actions API to scrape information from pages that require dynamic interaction
#
# ### Imports

# %%
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.actions.wheel_input import ScrollOrigin
import time

# %% [markdown]
# For this example, let's load the page for a specic *The Onion* TikTok video:

# %%
# Send HTTP request
driver.get("https://www.tiktok.com/@theonion/video/7473543012786752811")

# %% [markdown]
# Right off the bat, if we were to try to interact with this page, we will likely come across a Captcha or some form of human verification. Since this part cannot be automated, we will have to complete this by hand before we run the next part of the code.

# %% [markdown]
# Throughout this example, we will be looking for DOM elements that might not have been loaded when we try to look for them. To properly wait for the elements that we are searching for, we will use the following helper function

# %%
def wait_then_find(by_method, name, driver):
	element = WebDriverWait(driver, 20).until(
		EC.presence_of_element_located((By.CLASS_NAME, name))
	)
	return element

# %% [markdown]
# Once we completed this Captcha, by analyzing the DOM on this page, we see that TikTok uses specific class identifiers for different types of elements. One of such classes is `ejcng161`, which seems to be the unique class identifier for the number of comments text box right above the comments. We can use this to our advantage to get the total number of comments

# %%
num_comments_el = wait_then_find(By.CLASS_NAME, "ejcng161", driver)

# %% [markdown]
# This text box will be in a format like `136 comments`, so let's parse the number out of the text content. Since TikTok uses an infinite scroll-like interface to load comments, we need to scroll down to load all the comments into the DOM. Let's use this count we just got to define how much we need to scroll

# %%
total_num_comments = int(num_comments_el.text.split(' ')[0])
scroll_amount = total_num_comments * 25

print(f"Scrolling by {scroll_amount} for {total_num_comments} comments")
# Out:
# Scrolling by 3700 for 148 comments

# %% [markdown]
# Next, let's scroll the page in increments of 500, up to the amount specified

# %%
# scroll in increments of 500
scroll_pos = 0
while scroll_pos < scroll_amount:
	ActionChains(driver)\
		.scroll_by_amount(0, 500)\
		.perform()
	scroll_pos += 500
	time.sleep(1.5)

# %% [markdown]
# Once all comments are loaded, we now want to expand all replies to comments. In order to do this, we will traverse through each `View More` button to load as many replies as possible. We can do this by using the same strategy we used to get the total comments count and finding the unique class identifier for this kind of button, `ezgpko45`. Since this class identifier is also used for the `Hide` button, we want to filter out any non-`View More` button. In order to load as many replies as possible, we will continue to loop over all present `View More` buttons and click them until no new comment replies are loaded.

# %%
prev_num_comments = 0

# expand all "view more" buttons
while True:
	# get number of comment boxes
	num_comments = len(driver.find_elements(By.CLASS_NAME, "e1970p9w2"))

	# get all "view more" buttons
	comment_buttons = driver.find_elements(By.CLASS_NAME, "ezgpko45")
	view_mores = [vm for vm in comment_buttons if vm.find_element(By.TAG_NAME, "span").text != "Hide"]

	# stop trying if we did not get any new comments loaded
	if num_comments == prev_num_comments:
		break
	prev_num_comments = num_comments

	for vm in view_mores:
		try:
			button_text = vm.find_element(By.TAG_NAME, "span").text
		except Exception as e:
			continue

		ActionChains(driver)\
			.scroll_from_origin(ScrollOrigin.from_element(vm, 0, 0), 0, 35)\
			.pause(1)\
			.perform()
		driver.implicitly_wait(2)
		vm.click()
		driver.implicitly_wait(5)
	
	print(f"Found {len(driver.find_elements(By.CLASS_NAME, 'e1970p9w2')) - prev_num_comments} more replies!")
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# Cell In[28], line 26
#      20 except Exception as e:
#      21 	continue
#      23 ActionChains(driver)\
#      24 	.scroll_from_origin(ScrollOrigin.from_element(vm, 0, 0), 0, 35)\
#      25 	.pause(1)\
# ---> 26 	.perform()
#      27 driver.implicitly_wait(2)
#      28 vm.click()
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/selenium/webdriver/common/action_chains.py:94, in ActionChains.perform(self)
#      92 def perform(self) -> None:
#      93     """Performs all stored actions."""
# ---> 94     self.w3c_actions.perform()
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/selenium/webdriver/common/actions/action_builder.py:170, in ActionBuilder.perform(self)
#     168         enc["actions"].append(encoded)
#     169         device.actions = []
# --> 170 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:427, in WebDriver.execute(self, driver_command, params)
#     424     elif "sessionId" not in params:
#     425         params["sessionId"] = self.session_id
# --> 427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
#     429     self.error_handler.check_response(response)
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/selenium/webdriver/remote/remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/selenium/webdriver/remote/remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)    140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     838 elif isinstance(new_e, (OSError, HTTPException)):
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#     846 # Keep track of the error for the retry warning.
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     471 elif error and self._is_read_error(error):
#     472     # Read retry?
#     473     if read is False or method is None or not self._is_method_retryable(method):
# --> 474         raise reraise(type(error), error, _stacktrace)
#     475     elif read is not None:
#     476         read -= 1
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      37     if value.__traceback__ is not tb:
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#      41     value = None  # type: ignore[assignment]
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#     539 # Set properties that are used by the pooling layer.
#
# File ~/Documents/GitHub/DataDrivenHackathon/env/lib/python3.13/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     364 """Is the error actually a timeout? Will raise a ReadTimeout or pass"""
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#     372 if hasattr(err, "errno") and err.errno in _blocking_errnos:
#
# ReadTimeoutError: HTTPConnectionPool(host='localhost', port=50865): Read timed out. (read timeout=120)

# %% [markdown]
# Finally, let's print out the author and comment text for all of the comments we loaded

# %%
# get all comment boxes
comments = driver.find_elements(By.CLASS_NAME, "e1970p9w2")

print(f"{len(comments)} comments out of {total_num_comments} TikTok reported total found.\n")
# print all comment's text
for c in comments:
	print("Author: \n " + c.find_element(By.CLASS_NAME, "e1vx58lt0").text)
	print("Comment: \n" + c.find_element(By.TAG_NAME, "span").find_element(By.TAG_NAME, "p").text)
	print("")

driver.quit()
# Out:
# 98 comments out of 149 TikTok reported total found.
#
# Author:
#  Confused Person🎧🎸⚭
# Comment:
# Wow im supprised the onion is able to keep going in todays america
#
# Author:
#  raider_1941
# Comment:
# this video is like a decade old.
#
# Author:
#  shampoomaster42
# Comment:
# no 🤪
#
# Author:
#  Zylonpylon
# Comment:
# Old clip
#
# Author:
#  Confused Person🎧🎸⚭
# Comment:
# I know he is such a idiot
#
# Author:
#  fiona <3
# Comment:
# Listen to anything the maga Republican Party says and you’ll be surprised what you can say on air….😐
#
# Author:
#  Doobie Houser MD
# Comment:
# Why? Too many Magats will think it’s real?
#
# Author:
#  chowchow
# Comment:
# Why... it is the current state of 80% of Americans
#
# Author:
#  Brandon
# Comment:
# They just blend in with real news cuz reality is stupid
#
# Author:
#  Sloth
# Comment:
# It's because trump loves watching "the best documentaries"
#
# Author:
#  TheLeterminator
# Comment:
# and everyone doesn't get it lol. What happened to satire. I guess when the whole world is a joke then it's tough to tell the difference
#
# Author:
#  PhilA463
# Comment:
# dude hates anteaters. why is everyone in the comments talking about onions
#
# Author:
#  EJ Wont Let You Down
# Comment:
# “That’s what I told your producers cuz I didn’t want THEM to bring one” 🤣🪦
#
# Author:
#  Wes
# Comment:
# That’s my favorite part
#
# Author:
#  Dix
# Comment:
# I was expecting "after 15 years I can confirm, that's not where anteaters live"
#
# Author:
#  Natasha
# Comment:
# Hello🥰how are you doing
#
# Author:
#  chris_capXO
# Comment:
# Media literacy is concerning in these comments
#
# Author:
#  Natasha
# Comment:
# Hello 🥰how are you doing
#
# Author:
#  GenericEdgyUsername
# Comment:
# This has and always will be my favourite Onion Sketch
#
# Author:
#  Alus 🍉💛💙
# Comment:
# Too believable
#
# Author:
#  Natasha
# Comment:
# Hello🥰how are you doing
#
# Author:
#  Blair Brown
# Comment:
# The onion is the most trusted new source throughout the world. Most journalistic enterprises use three sources the onion uses 17 dozen.
#
# Author:
#  Vincent
# Comment:
# Most reliable source of facts around these days
#
# Author:
#  Mbc181
# Comment:
# I can relate to his level of apathy regarding career choices
#
# Author:
#  pineapple pizza 🇵🇸
# Comment:
# I think about this sketch all the time
#
# Author:
#  sarah !
# Comment:
# i wanted to see an anteater💔
#
# Author:
#  Kieran
# Comment:
# "open up about yourself"
#
# Author:
#  Paul
# Comment:
# The onion is a waste of data. Red, white and blue land. How is that not funnier than this.
#
# Author:
#  Your-Moms-Boyfriend
# Comment:
# lol that's why the onion fell off,cus real life got crazier
#
# Author:
#  Michael
# Comment:
# That would be me if I had ever become a biologist. I wouldn’t be a good interview. 😂
#
# Author:
#  Relax Rallex
# Comment:
# I miss her so much
#
# Author:
#  Natasha
# Comment:
# Hello🥰how are you doing
#
# Author:
#  MLungisi Tomas
# Comment:
# 🤣🤣🤣🤣🤣🤣 His not happy with the 15 years he spent
#
# Author:
#  BHJ
# Comment:
# Wait is this real why did they air this
#
# Author:
#  Makana
# Comment:
# Yes it’s completely real famous news clip that is real and true and famous
#
# Author:
#  boatstory3
# Comment:
# It’s real
#
# Author:
#  Actually Not Hayden
# Comment:
# New was just diff in the late 2000s morning shows got crazy
#
# Author:
#  Notmatp
# Comment:
# It just aired today
#
# Author:
#  seantgraf
# Comment:
# Yeah it's a famous real news clip
#
# Author:
#  Brittney
# Comment:
# i was thinking the same thing
#
# Author:
#  Genaro Morasco
# Comment:
# you def a conservative 🤣😂
#
# Author:
#  horseleatherfan
# Comment:
# Does a show called Today Now by The Onion sound off to you
#
# Author:
#  BHJ
# Comment:
# No horselestherfan it doesn’t
#
# Author:
#  Jschr23
# Comment:
# of course it is
#
# Author:
#  Kunz von Schlabotze-Hamwanich
# Comment:
# Way too realistic. 😳
#
# Author:
#  billywayne McWilliams
# Comment:
# like talking about ex wives
#
# Author:
#  Archangelcat
# Comment:
# No one knows the Onion is satire.
#
# Author:
#  mrrobot
# Comment:
# On the 16th year the would dance and talk and sing. Should have stuck around that next year
#
# Author:
#  Natasha
# Comment:
# Hello dear how are you doing ❤️
#
# Author:
#  Luna & Owi
# Comment:
# lets take bro to a party, he seems fun.
#
# Author:
#  yt/twtch: delamomanny
# Comment:
# Wow too early
#
# Author:
#  Brian D d
# Comment:
# At this point he’s not even trying to defend his career choices
#
# Author:
#  Rosh MaCapital
# Comment:
# they were not so interesting after the first 5 years, but I stayed 10 more years 😂😂😂
#
# Author:
#  KAMBAS
# Comment:
# its always theonion, man! 😭😭
#
# Author:
#  anthony20110
# Comment:
# I wish this was true lol
#
# Author:
#  Natasha
# Comment:
# Hello 🥰how are you doing
#
# Author:
#  sharongammell663
# Comment:
# I love The Onion! This is what I needed today. 🤣🤣🤣❤️❤️❤️
#
# Author:
#  Natasha
# Comment:
# Hello 🥰how are you doing
#
# Author:
#  𒐫 𒐫 𒐫 𒐫 𒐫 𒐫 𒐫 𒐫 𒐫 𒐫
# Comment:
# BABYLON BEE BETTER!!
#
# Author:
#  evancollins1990
# Comment:
# Hahaha not even remotely
#
# Author:
#  Natasha
# Comment:
# Hello dear how are you doing ❤️
#
# Author:
#  edli_a
# Comment:
# The onion used to be so good 😌
#
# Author:
#  Klitosaurus🇩🇰
# Comment:
# This is 17 years old.
#
# Author:
#  Natasha
# Comment:
# Hello 🥰how are you doing
#
# Author:
#  trickyricky
# Comment:
# my life is complete.the onion has found its way to my fyp..❤️
#
# Author:
#  Natasha
# Comment:
# Hello 🥰how are you doing
#
# Author:
#  Donald MacKenzie
# Comment:
# I honestly didn’t want to believe this company had fallen off this bad but here we are. Even progressives can’t pretend to laugh
#
# Author:
#  Chase
# Comment:
# This is really old
#
# Author:
#  Donald MacKenzie
# Comment:
# Huh weird I remember then being funny once
#
# Author:
#  SpectatorPathway
# Comment:
# You were less of a sensitive baby you mean?
#
# Author:
#  taime
# Comment:
# I love this video
#
# Author:
#  mule
# Comment:
# at least I found my spirit animal
#
# Author:
#  سلطان بن راجح
# Comment:
# meh
#
# Author:
#  Dorper
# Comment:
# 👌👌👌
#
# Author:
#  _________
# Comment:
# 💀💀💀
#
# Author:
#  glez1776
# Comment:
# 🤣🤣🤣
#
# Author:
#  aussiecynic
# Comment:
# 🤣🤣🤣🤣
#
# Author:
#  Lcloutier33
# Comment:
# 😳😳😳
#
# Author:
#  Natasha
# Comment:
# Hello🥰how are you doing
#
# Author:
#  daicrumb🏴󠁧󠁢󠁷󠁬󠁳󠁿
# Comment:
# 😂😂😂
#
# Author:
#  g._.williams
# Comment:
# @Rhys Hickey
#
# Author:
#  Natasha
# Comment:
# Hello🥰how are you doing
#
# Author:
#  camilleon
# Comment:
# 😁
#
# Author:
#  Traveling_Tobias
# Comment:
# 🤣🤣🤣
#
# Author:
#  Honest(6'2 btw)
# Comment:
# 😭
#
# Author:
#
# Comment:
# 😂😂😂
#
# Author:
#  bibbel
# Comment:
# 😂
#
# Author:
#  antisheditz
# Comment:
# ☹️☹️☹️
#
# Author:
#  Magic 8 Ball Fluid
# Comment:
# 💀
#
# Author:
#  user107922267495
# Comment:
# 😁
#
# Author:
#  Anthony Thrailkill
# Comment:
# 😂😂😂
#
# Author:
#  Natasha
# Comment:
# Hello 🥰how are you doing
#
# Author:
#  TheBacardiKing
# Comment:
# 🤣😂🤣
#
# Author:
#  Must visit Korea
# Comment:
# 😂
#
# Author:
#  Olai
# Comment:
# 😭😭😭
#
# Author:
#  thechainsaweccentric
# Comment:
# 🤣🤣🤣
#
# Author:
#  Dorzell King
# Comment:
# 🤣🤣🤣🤣🤣🤣
#
# Author:
#  Biden Aubrey
# Comment:
# Wow 😯, I actually do not think people with such integrity still exist 🥹 hazel thank you so much, God bless you.
